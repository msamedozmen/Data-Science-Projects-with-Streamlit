# %%
import pandas as pd 
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# %%
pd.options.display.float_format = "{:,.2f}".format

# %%
df = pd.read_csv("apps.csv")

# %%
df.drop(["Android_Ver","Last_Updated"],axis=1,inplace=True)

# %% [markdown]
# # Data Cleaning

# %%
df_clean = df.dropna()

# %%
df_clean.shape
# Out:
# (9367, 10)

# %%
df_clean = df_clean.drop_duplicates(subset=["App","Price","Type"])

# %%
df_clean.shape
# Out:
# (8199, 10)

# %% [markdown]
# # Find Highest Rated Apps

# %%
df_highest_rating = df_clean.sort_values("Rating",ascending=False,ignore_index=True,)

# %%
df_highest_rating
# Out:
#                                           App      Category  Rating  Reviews  \
# 0                         KBA-EZ Health Guide       MEDICAL    5.00        4
# 1                                Sway Medical       MEDICAL    5.00        3
# 2                           AJ Men's Grooming     LIFESTYLE    5.00        2
# 3                              FK Dedinje BGD        SPORTS    5.00       36
# 4                             CB VIDEO VISION   PHOTOGRAPHY    5.00       13
# ...                                       ...           ...     ...      ...
# 8194                              CR Magazine      BUSINESS    1.00        1
# 8195           FE Mechanical Engineering Prep        FAMILY    1.00        2
# 8196                        Speech Therapy: F        FAMILY    1.00        1
# 8197  Familial Hypercholesterolaemia Handbook       MEDICAL    1.00        2
# 8198                           Thistletown CI  PRODUCTIVITY    1.00        1
#
#       Size_MBs Installs  Type  Price Content_Rating        Genres
# 0        25.00        1  Free      0       Everyone       Medical
# 1        22.00      100  Free      0       Everyone       Medical
# 2        22.00      100  Free      0       Everyone     Lifestyle
# 3         2.60      100  Free      0       Everyone        Sports
# 4         2.60      100  Free      0       Everyone   Photography
# ...        ...      ...   ...    ...            ...           ...
# 8194      7.80      100  Free      0       Everyone      Business
# 8195     21.00    1,000  Free      0       Everyone     Education
# 8196     16.00       10  Paid  $2.99       Everyone     Education
# 8197     33.00      100  Free      0       Everyone       Medical
# 8198      6.60      100  Free      0       Everyone  Productivity
#
# [8199 rows x 10 columns]

# %%
df_highest_size =df_clean.sort_values("Size_MBs",ascending=False,ignore_index=True)

# %%
df_highest_size
# Out:
#                                  App            Category  Rating  Reviews  \
# 0     Talking Babsy Baby: Baby Games           LIFESTYLE    4.00   140995
# 1             Hungry Shark Evolution                GAME    4.50  6074334
# 2              Miami crime simulator                GAME    4.00   254518
# 3       Gangster Town: Vice District              FAMILY    4.30    65146
# 4                         Vi Trainer  HEALTH_AND_FITNESS    3.60      124
# ...                              ...                 ...     ...      ...
# 8194     Ad Remove Plugin for App2SD        PRODUCTIVITY    4.10       66
# 8195                ExDialer PRO Key       COMMUNICATION    4.50     5474
# 8196    My baby firework (Remove ad)              FAMILY    4.10       30
# 8197            Market Update Helper  LIBRARIES_AND_DEMO    4.10    20145
# 8198             Essential Resources  LIBRARIES_AND_DEMO    4.60      237
#
#       Size_MBs     Installs  Type  Price Content_Rating  \
# 0       100.00   10,000,000  Free      0       Everyone
# 1       100.00  100,000,000  Free      0           Teen
# 2       100.00   10,000,000  Free      0     Mature 17+
# 3       100.00   10,000,000  Free      0     Mature 17+
# 4       100.00        5,000  Free      0       Everyone
# ...        ...          ...   ...    ...            ...
# 8194      0.02        1,000  Paid  $1.29       Everyone
# 8195      0.02      100,000  Paid  $3.99       Everyone
# 8196      0.01        1,000  Paid  $0.99       Everyone
# 8197      0.01    1,000,000  Free      0       Everyone
# 8198      0.01       50,000  Free      0       Everyone
#
#                       Genres
# 0     Lifestyle;Pretend Play
# 1                     Arcade
# 2                     Action
# 3                 Simulation
# 4           Health & Fitness
# ...                      ...
# 8194            Productivity
# 8195           Communication
# 8196           Entertainment
# 8197        Libraries & Demo
# 8198        Libraries & Demo
#
# [8199 rows x 10 columns]

# %%
df_highest_reviews = df_clean.sort_values("Reviews",ascending=False,ignore_index=True)

# %%
df_highest_reviews
# Out:
#                                                  App            Category  \
# 0                                           Facebook              SOCIAL
# 1                                 WhatsApp Messenger       COMMUNICATION
# 2                                          Instagram              SOCIAL
# 3           Messenger – Text and Video Chat for Free       COMMUNICATION
# 4                                     Clash of Clans                GAME
# ...                                              ...                 ...
# 8194                             Wowkwis aq Ka'qaquj              FAMILY
# 8195                                          CB Fit  HEALTH_AND_FITNESS
# 8196                 ES Billing System (Offline App)        PRODUCTIVITY
# 8197  Ek Kahani Aisi Bhi Season 3 - The Horror Story              FAMILY
# 8198                                    Chenoweth AH             MEDICAL
#
#       Rating   Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 0       4.10  78158306      5.30  1,000,000,000  Free     0           Teen
# 1       4.40  69119316      3.50  1,000,000,000  Free     0       Everyone
# 2       4.50  66577313      5.30  1,000,000,000  Free     0           Teen
# 3       4.00  56642847      3.50  1,000,000,000  Free     0       Everyone
# 4       4.60  44891723     98.00    100,000,000  Free     0   Everyone 10+
# ...      ...       ...       ...            ...   ...   ...            ...
# 8194    5.00         1     49.00             10  Free     0       Everyone
# 8195    5.00         1      7.80             10  Free     0       Everyone
# 8196    5.00         1      4.20            100  Free     0       Everyone
# 8197    3.00         1      5.80            100  Free     0           Teen
# 8198    5.00         1     27.00            100  Free     0       Everyone
#
#                    Genres
# 0                  Social
# 1           Communication
# 2                  Social
# 3           Communication
# 4                Strategy
# ...                   ...
# 8194  Education;Education
# 8195     Health & Fitness
# 8196         Productivity
# 8197        Entertainment
# 8198              Medical
#
# [8199 rows x 10 columns]

# %%
content_rating = df_clean.Content_Rating.value_counts()

# %%
content_rating_df = pd.DataFrame({'Content_Rating': content_rating.index, 'Count': content_rating.values})

fig = px.pie(
    content_rating_df,
    values='Count',
    names='Content_Rating',
    title='Content Rating Distribution',
    labels=content_rating_df.index,
    hole=0.6,
    color_discrete_sequence=px.colors.sequential.Plasma
    
)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(
    plot_bgcolor='rgba(0, 0, 0, 0)',  # Set plot background color to transparent
    paper_bgcolor='rgb(0, 0, 0)',     # Set paper (the outer background) color to dark
)


fig.show()

# %%
df_clean.Installs = pd.to_numeric(df_clean.Installs.astype(str).str.replace(",",""))
df_intalls =df_clean[["App","Installs"]].groupby("Installs").count()

# %%
df_intalls = df_intalls.sort_values(by="App",ascending=False)
df_intalls.index = pd.Series(df_intalls.index).apply(lambda x: "+" + str(x) if x > 10000 else str(x))

# %%
df_installs =df_clean[["App","Installs"]]
df_installs = df_installs.sort_values(by="Installs",ascending=False)
df_installs["Installs"] = df_installs["Installs"].apply(lambda x: "+" + str(x) if x >= 10000 else str(x))

# %%
df_intalls
# Out:
#               App
# Installs
# +1000000     1417
# +100000      1096
# 10000         988
# +10000000     933
# 1000          698
# +5000000      607
# +500000       504
# +50000        457
# 5000          425
# 100           303
# +50000000     202
# 500           199
# +100000000    189
# 10             69
# 50             56
# +500000000     24
# +1000000000    20
# 5               9
# 1               3

# %%
fig =px.pie(
    df_intalls,
    values=df_intalls.App,
    names=df_intalls.index,
)
fig.update_traces(textposition='inside', textinfo='percent+label')


fig.show()

# %%
df_clean.Price = pd.to_numeric(df_clean.Price.astype(str).str.replace("$","",regex=False))

# %%
df_clean.sort_values(by="Price",ascending=False,ignore_index=True)
# Out:
#                               App   Category  Rating   Reviews  Size_MBs  \
# 0        I'm Rich - Trump Edition  LIFESTYLE    3.60       275      7.30
# 1              I AM RICH PRO PLUS    FINANCE    4.00        36     41.00
# 2               I Am Rich Premium    FINANCE    4.10      1867      4.70
# 3              I am rich(premium)    FINANCE    3.50       472      0.94
# 4                      💎 I'm rich  LIFESTYLE    3.80       718     26.00
# ...                           ...        ...     ...       ...       ...
# 8194  myAir™ for Air10™ by ResMed    MEDICAL    3.70       236     18.00
# 8195                AK Math Coach     FAMILY    3.60       283     18.00
# 8196         Forgotten Hill: Fall       GAME    4.40      1063     18.00
# 8197               AE Video Poker       GAME    4.00       721     18.00
# 8198               Subway Surfers       GAME    4.50  27722264     76.00
#
#         Installs  Type  Price Content_Rating     Genres
# 0          10000  Paid 400.00       Everyone  Lifestyle
# 1           1000  Paid 399.99       Everyone    Finance
# 2          50000  Paid 399.99       Everyone    Finance
# 3           5000  Paid 399.99       Everyone    Finance
# 4          10000  Paid 399.99       Everyone  Lifestyle
# ...          ...   ...    ...            ...        ...
# 8194       50000  Free   0.00       Everyone    Medical
# 8195       50000  Free   0.00       Everyone  Education
# 8196       50000  Free   0.00           Teen  Adventure
# 8197       50000  Free   0.00           Teen     Casino
# 8198  1000000000  Free   0.00   Everyone 10+     Arcade
#
# [8199 rows x 10 columns]

# %%
df_highest_revenue = df_clean.sort_values(by="Revenue",ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12904\2739265588.py in ?()
# ----> 1 df_highest_revenue = df_clean.sort_values(by="Revenue",ascending=False)
#
# c:\Users\MONSTER\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in ?(*args, **kwargs)
#     327                     msg.format(arguments=_format_argument_list(allow_args)),
#     328                     FutureWarning,
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#
# c:\Users\MONSTER\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6905         elif len(by):
#    6906             # len(by) == 1
#    6907
#    6908             by = by[0]
# -> 6909             k = self._get_label_or_level_values(by, axis=axis)
#    6910
#    6911             # need to rewrap column in Series to apply key function
#    6912             if key is not None:
#
# c:\Users\MONSTER\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1846                 .get_level_values(key)  # type: ignore[assignment]
#    1847                 ._values
#    1848             )
#    1849         else:
# -> 1850             raise KeyError(key)
#    1851
#    1852         # Check for duplicates
#    1853         if values.ndim > 1:
#
# KeyError: 'Revenue'

# %%
df_highest_revenue
# Out:
#                                  App   Category  Rating   Reviews  Size_MBs  \
# 9220                       Minecraft     FAMILY    4.50   2376564     19.00
# 5765                       I am rich  LIFESTYLE    3.80      3547      1.80
# 4606               I Am Rich Premium    FINANCE    4.10      1867      4.70
# 8825                   Hitman Sniper       GAME    4.60    408292     29.00
# 7151   Grand Theft Auto: San Andreas       GAME    4.40    348962     26.00
# ...                              ...        ...     ...       ...       ...
# 4508     myAir™ for Air10™ by ResMed    MEDICAL    3.70       236     18.00
# 4507                   AK Math Coach     FAMILY    3.60       283     18.00
# 4506            Forgotten Hill: Fall       GAME    4.40      1063     18.00
# 4505                  AE Video Poker       GAME    4.00       721     18.00
# 10835                 Subway Surfers       GAME    4.50  27722264     76.00
#
#          Installs  Type  Price Content_Rating                     Genres  \
# 9220     10000000  Paid   6.99   Everyone 10+  Arcade;Action & Adventure
# 5765       100000  Paid 399.99       Everyone                  Lifestyle
# 4606        50000  Paid 399.99       Everyone                    Finance
# 8825     10000000  Paid   0.99     Mature 17+                     Action
# 7151      1000000  Paid   6.99     Mature 17+                     Action
# ...           ...   ...    ...            ...                        ...
# 4508        50000  Free   0.00       Everyone                    Medical
# 4507        50000  Free   0.00       Everyone                  Education
# 4506        50000  Free   0.00           Teen                  Adventure
# 4505        50000  Free   0.00           Teen                     Casino
# 10835  1000000000  Free   0.00   Everyone 10+                     Arcade
#
#             Revenue
# 9220  69,900,000.00
# 5765  39,999,000.00
# 4606  19,999,500.00
# 8825   9,900,000.00
# 7151   6,990,000.00
# ...             ...
# 4508           0.00
# 4507           0.00
# 4506           0.00
# 4505           0.00
# 10835          0.00
#
# [8199 rows x 11 columns]

# %%
df_clean.Category.nunique()
df_clean.shape
# Out:
# (8199, 11)

# %%
top_categories= df_clean.Category.value_counts()

# %%
top_categories
# Out:
# FAMILY                 1610
# GAME                    910
# TOOLS                   719
# FINANCE                 302
# LIFESTYLE               302
# PRODUCTIVITY            301
# PERSONALIZATION         298
# MEDICAL                 292
# PHOTOGRAPHY             263
# BUSINESS                262
# SPORTS                  260
# COMMUNICATION           257
# HEALTH_AND_FITNESS      243
# NEWS_AND_MAGAZINES      204
# SOCIAL                  203
# TRAVEL_AND_LOCAL        187
# SHOPPING                180
# BOOKS_AND_REFERENCE     169
# VIDEO_PLAYERS           148
# DATING                  134
# EDUCATION               118
# MAPS_AND_NAVIGATION     118
# ENTERTAINMENT           102
# FOOD_AND_DRINK           94
# AUTO_AND_VEHICLES        73
# WEATHER                  72
# LIBRARIES_AND_DEMO       64
# HOUSE_AND_HOME           62
# ART_AND_DESIGN           61
# COMICS                   54
# PARENTING                50
# EVENTS                   45
# BEAUTY                   42
# Name: Category, dtype: int64

# %%
bar = px.bar(x=top_categories.index,y=top_categories.values)

# %%
bar.show()

# %%
top_categories_with_highes_dowload = df_clean.groupby("Category").agg({"Installs":pd.Series.sum})
top_categories_with_highes_dowload.sort_values("Installs",ascending=False,inplace=True)
top_categories_with_highes_dowload
# Out:
#                         Installs
# Category
# GAME                 13858762717
# COMMUNICATION        11039241530
# TOOLS                 8099724500
# PRODUCTIVITY          5788070180
# SOCIAL                5487841475
# PHOTOGRAPHY           4649143130
# FAMILY                4437579590
# VIDEO_PLAYERS         3916897200
# TRAVEL_AND_LOCAL      2894859300
# NEWS_AND_MAGAZINES    2369110650
# ENTERTAINMENT         2113660000
# BOOKS_AND_REFERENCE   1665791655
# PERSONALIZATION       1532352930
# SHOPPING              1400331540
# HEALTH_AND_FITNESS    1134006220
# SPORTS                1096431465
# BUSINESS               692018120
# LIFESTYLE              503742120
# MAPS_AND_NAVIGATION    503267560
# FINANCE                455312400
# WEATHER                361096500
# EDUCATION              352852000
# FOOD_AND_DRINK         211677750
# DATING                 140912410
# ART_AND_DESIGN         114233100
# HOUSE_AND_HOME          97082000
# AUTO_AND_VEHICLES       53129800
# LIBRARIES_AND_DEMO      52083000
# COMICS                  44931100
# MEDICAL                 39162676
# PARENTING               31116110
# BEAUTY                  26916200
# EVENTS                  15949410

# %%
horizontal_bar = px.bar(x=top_categories_with_highes_dowload.Installs,
                        y=top_categories_with_highes_dowload.index,
                        orientation="h")

horizontal_bar.update_layout(xaxis_title ="Number of Dowloads",
                             yaxis_title="Category"
)
horizontal_bar.show()

# %% [markdown]
# # Colour Scales in Plotly Charts and  Extracting Nested Data from a Column

# %%
genres = df_clean.Genres.str.split(";",expand=True).stack()
num_genres = genres.value_counts()
num_genres
# Out:
# Tools                      719
# Education                  587
# Entertainment              502
# Action                     304
# Lifestyle                  303
# Finance                    302
# Productivity               301
# Personalization            298
# Medical                    292
# Sports                     270
# Photography                263
# Business                   262
# Communication              258
# Health & Fitness           245
# Casual                     216
# News & Magazines           204
# Social                     203
# Simulation                 200
# Travel & Local             187
# Arcade                     185
# Shopping                   180
# Books & Reference          171
# Video Players & Editors    150
# Dating                     134
# Puzzle                     124
# Maps & Navigation          118
# Role Playing               111
# Racing                     103
# Action & Adventure          96
# Strategy                    95
# Food & Drink                94
# Educational                 93
# Adventure                   78
# Auto & Vehicles             73
# Weather                     72
# Pretend Play                68
# Brain Games                 65
# Libraries & Demo            64
# Art & Design                62
# House & Home                62
# Board                       57
# Comics                      54
# Parenting                   50
# Card                        46
# Events                      45
# Beauty                      42
# Casino                      37
# Music & Video               31
# Creativity                  31
# Trivia                      28
# Word                        22
# Music                       21
# Music & Audio                1
# dtype: int64

# %%
color_bar= px.bar(x=num_genres.index,
                  y=num_genres.values,
                  color=num_genres.values,
                  hover_name=num_genres.index,
                  color_continuous_scale="Agsunset")

color_bar.update_layout(xaxis_title="Genre",
                  yaxis_title ="Number of Aoos",
                  coloraxis_showscale=True
                  )

color_bar.show()

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_free_vs_paid = df_clean.groupby(["Category","Type"],as_index=False).agg({"App":pd.Series.count})

# %%
df_free_vs_paid.sort_values("App",ascending=False)
# Out:
#               Category  Type   App
# 19              FAMILY  Free  1456
# 25                GAME  Free   834
# 53               TOOLS  Free   656
# 21             FINANCE  Free   289
# 31           LIFESTYLE  Free   284
# ..                 ...   ...   ...
# 17       ENTERTAINMENT  Paid     2
# 24      FOOD_AND_DRINK  Paid     2
# 40           PARENTING  Paid     2
# 38  NEWS_AND_MAGAZINES  Paid     2
# 3    AUTO_AND_VEHICLES  Paid     1
#
# [61 rows x 3 columns]

# %%
g_bar = px.bar(df_free_vs_paid,
               x="Category",
               y="App",
               color="Type",
               title="Free vs Paid Apps by Category",
               barmode="group")

g_bar.update_layout(xaxis_title='Category',
                    yaxis_title='Number of Apps',
                    xaxis={'categoryorder':'total descending'},
                    yaxis=dict(type='log'))

g_bar.show()

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps

# %%
box_plot = px.box(df_clean,
                  y="Installs",
                  x="Type",
                  color="Type",
                  notched=True,
                  points="all",
                  title= "Me")

box_plot.update_layout(yaxis=dict(type='log'))
box_plot.show()

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category

# %%
df_paid_apps = df_clean[df_clean['Type'] == 'Paid']
box = px.box(df_paid_apps,
             x='Category',
             y='Price',
             title='How Much Can Paid Apps Earn?')

box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Price',
                  xaxis={'categoryorder':'max descending'},
                  yaxis=dict(type='log'))

box.show()

# %%
df_clean.sort_values("Size_MBs",ascending=False)
# Out:
#                                   App            Category  Rating  Reviews  \
# 9942   Talking Babsy Baby: Baby Games           LIFESTYLE    4.00   140995
# 10687          Hungry Shark Evolution                GAME    4.50  6074334
# 9943            Miami crime simulator                GAME    4.00   254518
# 9944     Gangster Town: Vice District              FAMILY    4.30    65146
# 3144                       Vi Trainer  HEALTH_AND_FITNESS    3.60      124
# ...                               ...                 ...     ...      ...
# 2648      Ad Remove Plugin for App2SD        PRODUCTIVITY    4.10       66
# 5798                 ExDialer PRO Key       COMMUNICATION    4.50     5474
# 2684     My baby firework (Remove ad)              FAMILY    4.10       30
# 7966             Market Update Helper  LIBRARIES_AND_DEMO    4.10    20145
# 4696              Essential Resources  LIBRARIES_AND_DEMO    4.60      237
#
#        Size_MBs   Installs  Type  Price Content_Rating                  Genres
# 9942     100.00   10000000  Free   0.00       Everyone  Lifestyle;Pretend Play
# 10687    100.00  100000000  Free   0.00           Teen                  Arcade
# 9943     100.00   10000000  Free   0.00     Mature 17+                  Action
# 9944     100.00   10000000  Free   0.00     Mature 17+              Simulation
# 3144     100.00       5000  Free   0.00       Everyone        Health & Fitness
# ...         ...        ...   ...    ...            ...                     ...
# 2648       0.02       1000  Paid   1.29       Everyone            Productivity
# 5798       0.02     100000  Paid   3.99       Everyone           Communication
# 2684       0.01       1000  Paid   0.99       Everyone           Entertainment
# 7966       0.01    1000000  Free   0.00       Everyone        Libraries & Demo
# 4696       0.01      50000  Free   0.00       Everyone        Libraries & Demo
#
# [8199 rows x 10 columns]
